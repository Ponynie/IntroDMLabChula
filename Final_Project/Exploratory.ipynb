# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data = pd.read_csv('/Users/ponynie/Developer/Python_Code/IntroDMLabChula/Final_Project/children anemia.csv')
sns.jointplot(x="Hemoglobin level adjusted for altitude and smoking (g/dl - 1 decimal)", y="Anemia level", data=data)
